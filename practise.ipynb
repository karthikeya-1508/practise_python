# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\__init__.py:38
#      34 del _hard_dependencies, _dependency, _missing_dependencies
#      36 try:
#      37     # numpy compat
# ---> 38     from pandas.compat import (
#      39         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      40     )
#      41 except ImportError as _err:  # pragma: no cover
#      42     _module = _err.name
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\compat\__init__.py:28
#      17 from pandas.compat._constants import (
#      18     IS64,
#      19     ISMUSL,
#    (...)     25     WARNING_CHECK_DISABLED,
#      26 )
#      27 import pandas.compat.compressors
# ...

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\__init__.py:38
#      34 del _hard_dependencies, _dependency, _missing_dependencies
#      36 try:
#      37     # numpy compat
# ---> 38     from pandas.compat import (
#      39         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      40     )
#      41 except ImportError as _err:  # pragma: no cover
#      42     _module = _err.name
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\compat\__init__.py:28
#      17 from pandas.compat._constants import (
#      18     IS64,
#      19     ISMUSL,
#    (...)     25     WARNING_CHECK_DISABLED,
#      26 )
#      27 import pandas.compat.compressors
# ...
